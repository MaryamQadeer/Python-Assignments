# %%
# Assignment # 3
# Question # 01
print("Question # 01")
print("Enter the operation number from the list that you want to perform:")
print("1- Addition")
print("2- Subtraction")
print("3- Multiplication")
print("4- Division")
print("5- Power")
operator = int(input())
input1 = int(input("Enter first number: "))
input2 = int(input("Enter second number: "))
if operator == 1 :
    print(input1 ,"+" , input2 , "=" , input1+input2)
elif operator == 2 :
    print(input1 ,"-" , input2 , "=" , input1-input2)
elif operator == 3 :
    print(input1 ,"x" , input2 , "=" , input1*input2)
elif operator == 4 :
    print(input1 ,"/" , input2 , "=" , input1/input2)
elif operator == 5 :
    print(input1 ," raised to power " , input2 , "=" , input1**input2)
else :
    print("You entered wrong value.")
# Question # 02
print("Question # 02")
list_check = [1,"to", 4.55 , "Manager", 'e', -9]
for item in list_check:
    if type(item) == int or type(item) == float:
        print("The value" , item , "is Numeric")
    else :
        print("The value" , item , "is not Numeric")
# Question # 03
print("Question # 03")
data_dic = {0:10 , 1:20, 2:30, 3:40, 4:50, 5:50}
print("Data Dictionary before adding key: " , data_dic)
data_dic.update({2:35})
data_dic.update({6:70})
print("Data Dictionary after adding key: " , data_dic)
# Question # 04
print("Question # 04")
data_dic_sum = {0:10 , 1:20, 2:30, 3:40, 4:50, 5:"Maryam"}
print("Data Dictionary : " , data_dic_sum)
sum = 0
for key in data_dic_sum:
    if type(data_dic_sum[key]) == int or type(data_dic_sum[key]) == float:
        sum +=data_dic_sum[key]
print("The sum of all items in dictionary is :",sum)
# Question # 05
print("Question # 05")
x = [1,4,7,8,3,4,5,5,5,6,1,5,7,3,2,7,7]
print("The list is : ",x)
unique = []
dup = []
dup_val = 0
for item in x:
  if item not in unique:
    unique.append(item)
for item in unique:
  for value in x:
    if item == value:
      dup_val += 1
      if dup_val == 2:
        dup.append(item)
        break
  dup_val = 0
print("The duplicates in the list are: ",dup)    
# Question # 06
print("Question # 06")
data_dic_check = {0:10 , 1:20, 2:30, 3:40, 4:50, 5:60, 6:70, 7:80}
print("Data Dictionary : " , data_dic_check)
user_check_key = int(input("Enter the key you want to search: "))
present = 0
for key in data_dic_check:
    if key == user_check_key:
        present = 1
if present == 1:
    print("The key is present in Data Dictionary.")
else:
    print("The key is not present in Data Dictionary.")
# Out:
# Question # 01
# Enter the operation number from the list that you want to perform:
# 1- Addition
# 2- Subtraction
# 3- Multiplication
# 4- Division
# 5- Power
# 1
# Enter first number: 2
# Enter second number: 5
# 2 + 5 = 7
# Question # 02
# The value 1 is Numeric
# The value to is not Numeric
# The value 4.55 is Numeric
# The value Manager is not Numeric
# The value e is not Numeric
# The value -9 is Numeric
# Question # 03
# Data Dictionary before adding key:  {0: 10, 1: 20, 2: 30, 3: 40, 4: 50, 5: 50}
# Data Dictionary after adding key:  {0: 10, 1: 20, 2: 35, 3: 40, 4: 50, 5: 50, 6: 70}
# Question # 04
# Data Dictionary :  {0: 10, 1: 20, 2: 30, 3: 40, 4: 50, 5: 'Maryam'}
# The sum of all items in dictionary is : 150
# Question # 05
# The list is :  [1, 4, 7, 8, 3, 4, 5, 5, 5, 6, 1, 5, 7, 3, 2, 7, 7]
# The duplicates in the list are:  [1, 4, 7, 3, 5]
# Question # 06
# Data Dictionary :  {0: 10, 1: 20, 2: 30, 3: 40, 4: 50, 5: 60, 6: 70, 7: 80}
# Enter the key you want to search: 7
# ...
