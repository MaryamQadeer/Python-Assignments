# %%
# Assignment # 2
# Question # 01
print("Question # 01")
english = int(input("Enter marks for English:"))
urdu = int(input("Enter marks for Urdu:"))
maths = int(input("Enter marks for Maths:"))
science = int(input("Enter marks for Science:"))
computer = int(input("Enter marks for Computer:"))
total = ( ( english + urdu + maths + science + computer ) * 100 ) / 500
if total >= 80 :
    print("Your Grade is A+")
elif total >=70 and total < 80 :
    print("Your Grade is A")
elif total >=60 and total < 70 :
    print("Your Grade is B")
elif total >=50 and total < 60 :
    print("Your Grade is D")
elif total >=40 and total < 50 :
    print("Your Grade is E")
else :
    print("You have Failed")
# Question # 02
print("Question # 02")
number = int(input("Enter number to check whether it is Odd/Even: "))
if number % 2 == 0:
    print("The number is Even.")
else: 
    print("The number is Odd.")
# Question # 03
print("Question # 03")
list_number = [1,2,3,4,5,6,7,8,9,4,5,5,8,4,7]
print("List",list_number)
length = len(list_number)
print("The length of the list is",length)
# Question # 04
print("Question # 04")
numbers = [1,2,3,9,4,57,5,6,6,9,8,5,8,4,7]
print("List",numbers)
sum = 0
for item in numbers:
    sum += item
print("The sum of all items in the list is:",sum)
# Question # 05
print("Question # 05")
number_largest = [1,2,3,9,4,22,11,36,44,99,5,8,4,7]
print("List",number_largest)
largest = 0
for item in number_largest:
    if largest < item:
        largest = item
print("The largest of all numbers in the list is:",largest)
# Question # 06
print("Question # 06")
number_list = [1,2,3,9,4,22,11,36,44,99,5,8,4,7]
print("List",number_list)
print("The numbers which are less than 5 from the given list are:")
for item in number_list:
    if item < 5:
        print(item)
# Out:
# Question # 01
# Enter marks for English:98
# Enter marks for Urdu:78
# Enter marks for Maths:98
# Enter marks for Science:68
# Enter marks for Computer:98
# Your Grade is A+
# Question # 02
# Enter number to check whether it is Odd/Even: 7
# The number is Odd.
# Question # 03
# List [1, 2, 3, 4, 5, 6, 7, 8, 9, 4, 5, 5, 8, 4, 7]
# The length of the list is 15
# Question # 04
# List [1, 2, 3, 9, 4, 57, 5, 6, 6, 9, 8, 5, 8, 4, 7]
# The sum of all items in the list is: 134
# Question # 05
# List [1, 2, 3, 9, 4, 22, 11, 36, 44, 99, 5, 8, 4, 7]
# The largest of all numbers in the list is: 99
# Question # 06
# List [1, 2, 3, 9, 4, 22, 11, 36, 44, 99, 5, 8, 4, 7]
# The numbers which are less than 5 from the given list are:
# 1
# 2
# 3
# 4
# 4
