# %%
""" Question # 01 """
student = {
  "first_name" : "Maryam",
  "last_name" : "Qadeer",
  "age" : 24,
  "city" : "Karachi"
}
print(student)
student["qualification"] = "B.E";
print(student)
student["qualification"] = "High Academic Level";
print(student)
student.pop("qualification")
print(student)

""" Question # 02 """
cities = {
  "Sukkur" : {
    "country" : "Pakistan",
    "population" : 500000,
    "fact" : "Interior Sindh"
  },
  "Karachi" : {
    "country" : "Pakistan",
    "population" : 100000000,
    "fact" : "Biggest city in Sindh"
  }, 
  "Islamabad" : {
    "country" : "Pakistan",
    "population" : 350000,
    "fact" : "Capital"
  }
}

print(cities["Sukkur"])
print(cities["Karachi"])
print(cities["Islamabad"])

""" Question # 03 """

age = int(input("Enter your Age: "))
if age < 3 and age > 0:
  print("Your Ticket is free.")
elif age > 3 and age <= 12:
  print("Your Ticket Price is 10$.")
elif age > 12:
  print("Your Ticket Price is 15$.")
else:
  print("You have entered invalid age.")
  
""" Question # 04 """

def favorite_book(title):
  print("One of my Favourite book is " , title)
  
favorite_book("The Alchemist")

""" Question # 05 """
from random import randint
print("-----------------Guess Game-----------------")
random_number = randint(1,30)
for chances in range(3):
  print("-----------------",chances+1," Chance-----------------")
  guess = int(input("Enter your guess: "))
  if chances != 3:
    if guess > random_number and guess <=30 and guess > 0:
      print("You guess too High.")
      chances += 1
    elif guess < random_number and guess <=30 and guess > 0:
      print("You guess too Low.")
      chances += 1
    elif guess == random_number:
      print("Congratulations!!! You have won.")
      break
    else:
      print("You entered out of range number.")
  if chances == 3:
    print("Sorry!!! You lost.")
# Out:
# {'first_name': 'Maryam', 'last_name': 'Qadeer', 'age': 24, 'city': 'Karachi'}
# {'first_name': 'Maryam', 'last_name': 'Qadeer', 'age': 24, 'city': 'Karachi', 'qualification': 'B.E'}
# {'first_name': 'Maryam', 'last_name': 'Qadeer', 'age': 24, 'city': 'Karachi', 'qualification': 'High Academic Level'}
# {'first_name': 'Maryam', 'last_name': 'Qadeer', 'age': 24, 'city': 'Karachi'}
# {'country': 'Pakistan', 'population': 500000, 'fact': 'Interior Sindh'}
# {'country': 'Pakistan', 'population': 100000000, 'fact': 'Biggest city in Sindh'}
# {'country': 'Pakistan', 'population': 350000, 'fact': 'Capital'}
# Enter your Age: 15
# Your Ticket Price is 15$.
# One of my Favourite book is  The Alchemist
# -----------------Guess Game-----------------
# ----------------- 1  Chance-----------------
# Enter your guess: 5
# You guess too Low.
# ----------------- 2  Chance-----------------
# Enter your guess: 69
# You entered out of range number.
# ----------------- 3  Chance-----------------
# ...
